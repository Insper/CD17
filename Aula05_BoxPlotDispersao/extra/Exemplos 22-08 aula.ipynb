# %% [markdown]
# Alguns exemplos feitos na semana de 13/08

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dom2015 = pd.read_csv("DOM2015csv.zip", compression = "zip")

# %%
dom2015 = dom2015[dom2015.V4621!=999999999999]

# %%
dom2015.V4621.plot(kind="box")

# %%
ganham_menos = dom2015[dom2015.V4621 < 4000]

# %%
ganham_menos.V4621.describe()
# Out:
# count    109878.000000
# mean        925.863621
# std         734.142089
# min           0.000000
# 25%         400.000000
# 50%         780.000000
# 75%        1200.000000
# max        3997.000000
# Name: V4621, dtype: float64

# %%
ganham_menos.V4621.quantile(0.3333333)
# Out:
# 510.0

# %%
ganham_menos.V4621.plot(kind="box")

# %%
ganham_menos.boxplot(column="V4621",  by="V0220", figsize=(20,20))

# %%
ganham_menos[ganham_menos.V0220==4].V4621.describe()
# Out:
# count    9486.000000
# mean      716.432532
# std       543.846509
# min         0.000000
# 25%       315.000000
# 50%       788.000000
# 75%       800.000000
# max      3980.000000
# Name: V4621, dtype: float64
